# %%
# load libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# load CSV as Pandas dataframe
filename = "/home/emma/Documents/research/gnn-dna/figures/wandb_export_2023-06-03T15_44_54.856-04_00.csv"
df1 = pd.read_csv(filename)
df1
# Out:
#      Step  gnn-256-knn-7 - val_loss  gnn-256-knn-7 - val_loss__MIN  \
# 0       0                       NaN                            NaN
# 1       1                  0.000183                       0.000183
# 2       3                       NaN                            NaN
# 3       4                  0.000158                       0.000158
# 4       5                       NaN                            NaN
# ..    ...                       ...                            ...
# 195   215                  0.000014                       0.000014
# 196   216                       NaN                            NaN
# 197   217                  0.000006                       0.000006
# 198   218                       NaN                            NaN
# 199   219                  0.000009                       0.000009
#
#      gnn-256-knn-7 - val_loss__MAX  gnn-256-knn-7 - train_loss  \
# 0                              NaN                    0.000252
# 1                         0.000183                         NaN
# 2                              NaN                    0.000018
# 3                         0.000158                         NaN
# 4                              NaN                    0.000013
# ..                             ...                         ...
# 195                       0.000014                         NaN
# 196                            NaN                    0.000003
# 197                       0.000006                         NaN
# 198                            NaN                    0.000003
# 199                       0.000009                         NaN
#
#      gnn-256-knn-7 - train_loss__MIN  gnn-256-knn-7 - train_loss__MAX  \
# 0                           0.000252                         0.000252
# 1                                NaN                              NaN
# 2                           0.000018                         0.000018
# 3                                NaN                              NaN
# 4                           0.000013                         0.000013
# ..                               ...                              ...
# 195                              NaN                              NaN
# 196                         0.000003                         0.000003
# 197                              NaN                              NaN
# 198                         0.000003                         0.000003
# 199                              NaN                              NaN
#
#      mlp-256 - val_loss  mlp-256 - val_loss__MIN  mlp-256 - val_loss__MAX  \
# 0                   NaN                      NaN                      NaN
# 1              0.000855                 0.000855                 0.000855
# 2                   NaN                      NaN                      NaN
# 3              0.000317                 0.000317                 0.000317
# 4                   NaN                      NaN                      NaN
# ..                  ...                      ...                      ...
# 195            0.000007                 0.000007                 0.000007
# 196                 NaN                      NaN                      NaN
# 197            0.000007                 0.000007                 0.000007
# 198                 NaN                      NaN                      NaN
# 199            0.000008                 0.000008                 0.000008
#
#      mlp-256 - train_loss  mlp-256 - train_loss__MIN  \
# 0                0.000739                   0.000739
# 1                     NaN                        NaN
# 2                0.000042                   0.000042
# 3                     NaN                        NaN
# 4                0.000042                   0.000042
# ..                    ...                        ...
# 195                   NaN                        NaN
# 196              0.000008                   0.000008
# 197                   NaN                        NaN
# 198              0.000008                   0.000008
# 199                   NaN                        NaN
#
#      mlp-256 - train_loss__MAX
# 0                     0.000739
# 1                          NaN
# 2                     0.000042
# 3                          NaN
# 4                     0.000042
# ..                         ...
# 195                        NaN
# 196                   0.000008
# 197                        NaN
# 198                   0.000008
# 199                        NaN
#
# [200 rows x 13 columns]

# %%
# extract mlp-256-train and val
mlp256_train = df1["mlp-256 - train_loss"].dropna()
mlp256_val = df1["mlp-256 - val_loss"].dropna()

# extract gnn-256-knn-7 train and val
gnn256_train = df1["gnn-256-knn-7 - train_loss"].dropna()
gnn256_val = df1["gnn-256-knn-7 - val_loss"].dropna()

# %%
# mlp256_train = mlp256_train.dropna()
mlp256_train
# Out:
# 0      0.000739
# 2      0.000042
# 4      0.000042
# 6      0.000030
# 8      0.000028
#          ...
# 190    0.000008
# 192    0.000008
# 194    0.000008
# 196    0.000008
# 198    0.000008
# Name: mlp-256 - train_loss, Length: 100, dtype: float64

# %%
# plot mlp-256 vs gnn-256-knn-7
plt.plot()

# %%
# plot gnn-64-knn-3 vs -5 vs -7

# %%
# plot Ngnn-256-knn-3-noise-0003 vs Ngnn-256-knn-3 no noise
